# %% [markdown]
# # Task 1: Exploring and Visualizing Iris Dataset
#
# ## Introduction
#
# In this task, we will explore and visualize the Iris dataset using Python. The main objective is to understand how to load a dataset, inspect its structure, and perform basic data visualization techniques such as scatter plots, histograms, and box plots. This helps in gaining insights about data distribution and relationships between different variables.

# %% [markdown]
# The following libraries are imported for data manipulation, analysis, and visualization.

# %%
#Importing Libraries
import pandas as pd

iris= pd.read_csv("iris.csv")

# %% [markdown]
# ## Dataset Description
#
# The Iris dataset is a well-known dataset in machine learning and data analysis. It contains information about three different species of iris flowers: Setosa, Versicolor, and Virginica. The dataset includes four main features: sepal length, sepal width, petal length, and petal width. It is commonly used for classification and data visualization tasks.

# %%
#Loading dataset
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Dataset Structure and Inspection
#
# This section explores the basic structure of the dataset.

# %%
#Dataset Shape
print("Dataset Shape:")
print(iris.shape)
# Out:
# Dataset Shape:
# (150, 5)

# %%
#Column Names
print("Dataset Columns:")
print(iris.columns)
# Out:
# Dataset Columns:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
#First five rows
print("First 5 Rows:")
print(iris.head())
# Out:
# First 5 Rows:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#Statistical summary
print(iris.describe())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# Data Cleaning and Preparation
# Checking for missing values and duplicate records to ensure data quality.

# %%
# Check missing values

print(iris.isnull().sum())
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# Check duplicate records

print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 3

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# The following visualizations help understand relationships, distributions, and variations within the dataset.

# %% [markdown]
# ### 1. Scatter Plot
# This scatter plot is used to analyze the relationship between Sepal Length and Petal Length.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.scatter(df['sepal_length'], df['petal_length'])

plt.title("Sepal Length vs Petal Length")
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")

plt.show()

# %% [markdown]
# ### Observation
#
# The scatter plot shows a positive relationship between sepal length and petal length. As sepal length increases, petal length generally increases as well.

# %% [markdown]
# ### 2. Histogram
# This histogram shows the distribution of Sepal Length values in the dataset.

# %%
plt.figure(figsize=(8,5))

plt.hist(df['sepal_length'], bins=10)

plt.title("Distribution of Sepal Length")
plt.xlabel("Sepal Length")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ### Observation
#
# The histogram shows how sepal length values are distributed across the dataset. Most observations are concentrated around the middle range.

# %% [markdown]
# ### 3. Box Plot
# This box plot helps identify outliers and understand the spread of Sepal Length values.

# %%
import seaborn as sns

plt.figure(figsize=(8,5))

sns.boxplot(y=df['sepal_length'])

plt.title("Box Plot of Sepal Length")

plt.show()

# %% [markdown]
# ### Observation
#
# The box plot shows the distribution and spread of sepal length values. It also helps identify any potential outliers in the dataset.

# %%
#Sepal vs Petal length
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(
    data=iris,
    x="sepal_length",
    y="petal_length",
    hue="species"
)

plt.title("Sepal Length vs Petal Length")
plt.show()

# %%
#Distribution of sepal length
sns.histplot(
    iris["sepal_length"],
    bins=20,
    kde=True
)

plt.title("Distribution of Sepal Length")
plt.show()

# %%
#Summary
print("TASK 1 SUMMARY")
print("----------------")

print("Shape:", iris.shape)

print("\nColumns:")
print(iris.columns)

print("\nFirst 5 Rows:")
print(iris.head())

print("\nStatistical Summary:")
print(iris.describe())
# Out:
# TASK 1 SUMMARY
# ----------------
# Shape: (150, 5)
#
# Columns:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')
#
# First 5 Rows:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
#
# Statistical Summary:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# ...

# %% [markdown]
# ## Conclusion
#
# The Iris dataset was successfully explored and visualized. Scatter plots were used to analyze relationships between variables, histograms were used to study data distribution, and box plots were used to identify outliers and data spread. These visualizations provide useful insights into the characteristics of the Iris dataset.
